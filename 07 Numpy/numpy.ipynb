# %% [markdown]
# #### Numpy Arrays
#
#     1D Array
#     2D Array
#     3D Array

# %%
import numpy as np

# 1D Array
a = [1, 2, 3]
print(type(a))
a1 = np.array(a)
print(type(a1))
print(a1.shape, a1.size, a1.dtype)
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>
# (3,) 3 int64

# %%
# 2D Array
a_2d = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
print(type(a_2d))
np_2d = np.array(a_2d)
print(type((np_2d)))
print(np_2d.shape, np_2d.dtype, np_2d.size)
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>
# (3, 3) int64 9

# %% [markdown]
# #### 3D Array

# %%
a_3d = [[[1, 2, 3], [4, 5, 6]], [[7, 8, 9], [0, 1, 2]]]
print(type(a_3d))
np_3d = np.array(a_3d)
print(type(np_3d))
print(np_3d.shape, np_3d.size, np_3d.dtype)

class_a_st_ranks = ["a", "b"]
class_a_st_2_ranks = ["c", "d"]
class_b_st_3_ranks = ["e", "f"]
class_b_st_4_ranks = ["g", "h"]
class_a = [class_a_st_ranks, class_a_st_2_ranks]
class_b = [class_b_st_3_ranks, class_b_st_4_ranks]
a_3d_str = [class_a, class_b]
print(type(a_3d_str))
np_3d_str = np.array(a_3d_str)
print(type(np_3d_str))
print(np_3d_str.shape, np_3d_str.size, np_3d_str.dtype)
# Out:
# <class 'list'>
# <class 'numpy.ndarray'>
# (2, 2, 3) 12 int64
# <class 'list'>
# <class 'numpy.ndarray'>
# (2, 2, 2) 8 <U1

# %% [markdown]
# #### List vs Numpy

# %%
# On NP Array looping is not required for multiplication
a = [1, 2, 3]
a1 = a * 3
print(a1)
np_a = np.array(a)
np_a1 = np_a * 3
print(np_a1)
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]
# [3 6 9]

# %%
# On NP Array looping is not required for addition
# list will not support
try:
    np_a = np.array(a)
    np_a1 = np_a + 3
    print(np_a1)
    a = [1, 2, 3]
    a1 = a + 3
    print(a1)
except Exception as ex:
    print(ex)
# Out:
# [4 5 6]
# can only concatenate list (not "int") to list

# %% [markdown]
# #### Aggregate Functions on Numpy
#     Sum
#     Mean
#     Mode
#     Median
#     Count
#     Std

# %%
a = np.array(range(1, 30, 6))
sum_ = np.sum(a)
mean_ = np.mean(a)
max_ = np.max(a)
min_ = np.min(a)
std_ = np.std(a)
count_ = np.size(a)
print(min_, max_, count_, mean_, std_)
# Out:
# 1 25 5 13.0 8.48528137423857

# %%
a_3d = [[[1, 2, 3], [4, 5, 6]], [[7, 8, 9], [0, 1, 2]]]
np_3d = np.array(a_3d)

axis_0_sum = np_3d.sum(axis=0)
axis_0_sum
axis_1_sum = np_3d.sum(axis=1)
axis_0_sum, axis_1_sum

axis_0_prod = np_3d.prod(axis=0)
axis_0_prod
axis_1_prod = np_3d.prod(axis=1)
axis_0_prod, axis_1_prod
# Out:
# (array([[ 7, 16, 27],
#         [ 0,  5, 12]]),
#  array([[ 4, 10, 18],
#         [ 0,  8, 18]]))

# %% [markdown]
# #### Generate Data using Numpy

# %%
a = list(range(0, 10, 3))
a
np_a = np.array(a)
np_a
try:
    a = list(range(0.9, 10, 3.9))
    a
except Exception as ex:
    print(ex)
# Out:
# 'float' object cannot be interpreted as an integer

# %%
np_float_list = np.arange(0.3, 10, 3.9)
np_float_list
# Out:
# array([0.3, 4.2, 8.1])

# %% [markdown]
# #### Equally Spaced Values - linspace

# %%
c1 = np.linspace(2, 10, 4)
c1
# Out:
# array([ 2.        ,  4.66666667,  7.33333333, 10.        ])

# %%
d1 = np.linspace(2, 100, 3)
d1
# Out:
# array([  2.,  51., 100.])

# %% [markdown]
# #### Randomly Generated Data

# %%
r1 = np.random.random(size=10)
r1
# Out:
# array([0.32782452, 0.73064287, 0.09772516, 0.39508005, 0.25059973,
#        0.65218793, 0.0248175 , 0.52798413, 0.34858453, 0.68154465])

# %%
r2 = np.random.randint(low=4, high=44, size=10)
r2
# Out:
# array([34, 12, 33,  8, 43, 11, 27, 21, 34, 29], dtype=int32)

# %%
d = ["Utkarsh", "Rahul", "Raman"]
d1 = np.array(d)
print(d1, d1.dtype)
# Out:
# ['Utkarsh' 'Rahul' 'Raman'] <U7

# %% [markdown]
# #### Random normal distribution

# %%
np.random.normal(loc=5.5, scale=0.5 / 3)
# Out:
# 5.285173031070223

# %%
heights = np.random.normal(loc=5.5, scale=0.5 / 3, size=190)
print(heights)
# Out:
# [5.64028797 5.43861693 5.49144372 5.44161866 5.58932522 5.53434967
#  5.52803905 5.3783727  5.52312794 5.42847291 5.49976914 5.25331285
#  5.40642636 5.93450734 5.49750295 5.6387378  5.61284561 5.53584138
#  5.3474352  5.38464468 5.4792949  5.54907072 5.56294091 5.59692542
#  5.44523826 5.44717807 5.52254752 5.43078919 5.49663932 5.56453825
#  5.47599908 5.44678188 5.42910795 5.28205986 5.40530102 5.1100347
#  5.48297246 5.51665219 5.41577973 5.57191334 5.58044998 5.60155091
#  5.63120389 5.37889868 5.33866045 5.52940546 5.56601261 5.27868221
#  5.32942804 5.42288014 5.4129785  5.56137266 5.69140505 5.38060235
#  5.57693774 5.54601451 5.23798699 5.29127046 5.54784995 5.35770214
#  5.76920008 5.29188125 5.4222424  5.84120858 5.89794445 5.25057299
#  5.23474965 5.37926309 5.55818351 5.03675519 5.21768026 5.49012398
#  5.87782355 5.5223418  5.64277518 5.35043876 5.23988046 5.44689988
#  5.60597743 5.76257018 5.83476688 5.61938743 5.39481377 5.57179679
#  5.40802833 5.4686374  5.71363783 5.54922394 5.51639748 5.38539767
#  5.49064393 5.59865652 5.30405363 5.55601392 5.29136842 5.41751477
#  5.56537257 5.30695918 5.67761434 5.31658158 5.07935215 5.88566547
#  5.08802701 5.35992061 5.55964719 5.69227429 5.53494175 5.3843504
#  5.29536947 5.29043231 5.33639621 5.51489475 5.57795121 5.28991267
#  5.54234875 5.67618757 5.55273729 5.51411373 5.49863957 5.37090356
#  5.41119319 5.73409025 5.24501287 5.62195836 5.45332838 5.44266614
#  5.60747747 5.13236557 5.51798896 5.35454816 5.3882464  5.62065247
#  5.57959541 5.51706212 5.35989901 5.59745427 5.63082657 5.23524413
#  5.64257038 5.27176305 5.35854272 5.37822831 5.50641037 5.42607874
#  5.51048764 5.38268436 5.40427212 5.42153994 5.50636284 5.27101959
#  5.51062098 5.27291411 5.67245744 5.40654708 5.8097971  5.49342021
#  5.61768356 5.49474998 5.24726221 5.226217   5.58520733 5.90290547
#  5.30154585 5.35838923 5.71009129 5.63497718 5.57875848 5.79734358
#  5.37002256 5.40601513 5.37519643 5.41967806 5.67098525 5.59116748
#  5.46626511 5.25767527 5.41874957 5.46587004 5.46798406 5.51764044
#  5.41605671 5.46382998 5.68754882 5.42241638 5.40921385 5.82097821
#  5.63854501 5.25248823 5.46864746 5.30292015]

# %%
import seaborn as sns

sns.histplot(data=heights, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
heights.mean(), heights.std()
# Out:
# (np.float64(5.478565961492646), np.float64(0.16439887060486058))

# %% [markdown]
# # Other mathematical functions can be applied using numpy

# %%
a = np.random.randint(low=1, high=50, size=5)
print(a)
a_square = np.square(a)
print(a_square)
a_sqrt = np.sqrt(a)
print(a_sqrt.round(3))
# Out:
# [ 4 22 23 14 37]
# [  16  484  529  196 1369]
# [2.    4.69  4.796 3.742 6.083]

# %%
a_sqrt**2
# Out:
# array([ 4., 22., 23., 14., 37.])

# %%
a_sqrt**3
# Out:
# array([  8.        , 103.18914672, 110.30412504,  52.38320341,
#        225.06221362])

# %%
np.exp(1)
# Out:
# np.float64(2.718281828459045)

# %%
np.exp(a_sqrt)
# Out:
# array([  7.3890561 , 108.898446  , 121.00495841,  42.16782067,
#        438.23817026])

# %%
np.log(a_sqrt)
# Out:
# array([0.69314718, 1.54552123, 1.56774711, 1.31952866, 1.80545896])

# %% [markdown]
# #### Calculate sin, cos , tan you require to conver tot radian

# %%
# in order to calculate sin, cos , tan you require to conver tot radian
angle_deg = [0, 30, 45, 60, 90]
print(angle_deg)
angle_rad = np.radians(angle_deg)
print(angle_rad.round(3))
# Out:
# [0, 30, 45, 60, 90]
# [0.    0.524 0.785 1.047 1.571]

# %%
np.sin(angle_rad).round(3)
# Out:
# array([0.   , 0.5  , 0.707, 0.866, 1.   ])

# %%
np.cos(angle_rad).round(3)
# Out:
# array([1.   , 0.866, 0.707, 0.5  , 0.   ])

# %%
np.tan(angle_rad.round(3))
# Out:
# array([ 0.00000000e+00,  5.77885359e-01,  9.99203990e-01,  1.73126087e+00,
#        -4.90982594e+03])

# %%
x = [0.1, 0.3, 1, 0.5, 0.8]
rad = np.asin(x)
print(rad.round(3))
deg = np.degrees(rad)
print(deg.round(3))
# Out:
# [0.1   0.305 1.571 0.524 0.927]
# [ 5.739 17.458 90.    30.    53.13 ]

# %%
np.acos(x), np.atan(x)
# Out:
# (array([1.47062891, 1.26610367, 0.        , 1.04719755, 0.64350111]),
#  array([0.09966865, 0.29145679, 0.78539816, 0.46364761, 0.67474094]))
